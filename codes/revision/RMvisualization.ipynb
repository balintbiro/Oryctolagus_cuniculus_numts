# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import anderson, wilcoxon, ttest_ind

# %%
alignments=pd.read_csv('../../data/filtered_alignments.csv',index_col=0)
alignments.head(n=5)
# Out:
#           score  chr_id  chr_start  chr_no_letters chr_strand     chr_size  \
# 61902        79    14.0  5159068.0           422.0          +  163896628.0
# 1505873      40    14.0  5159511.0           243.0          +  163896628.0
# 5179730     104    14.0  5159515.0           238.0          +  163896628.0
# 36807789     60    14.0  5159511.0           190.0          +  163896628.0
# 40825691     60    14.0  5159508.0           245.0          +  163896628.0
#
#             scf_id  scf_start  scf_no_letters scf_strand   scf_size  \
# 61902     GL019308    18580.0           448.0          -    88228.0
# 1505873   GL018741  1655521.0           219.0          +  2352391.0
# 5179730   GL018705  5295519.0           235.0          +  6124611.0
# 36807789  GL018706  2938370.0           182.0          +  5787221.0
# 40825691  GL018706   871592.0           245.0          -  5787221.0
#
#                                             blocks      EG2_val      E-val
# 61902     72,0:3,27,0:2,122,0:19,68,0:1,100,0:1,33  EG2=8.4e-21  E=2.7e-24
# 1505873                   74,21:0,37,1:0,30,2:0,78    EG2=0.031  E=0.00026
# 5179730                          130,1:0,36,2:0,69  EG2=1.1e-32  E=2.4e-34
# 36807789           110,3:0,14,1:0,16,3:0,26,1:0,16  EG2=9.2e-12    E=2e-13
# 40825691                         57,0:1,80,1:0,107  EG2=9.2e-12    E=2e-13

# %%
RMresult=pd.read_csv('../../data/RMResults.csv',index_col=0)
RMresult
# Out:
#       sw_score  perc_div  perc_del  perc_insert                        qry_id  \
# 1           15      15.9       5.0          1.2  11:32103023-32103625_ChrDown
# 2           15      15.9       5.0          1.2  11:32103055-32103689_ChrDown
# 3           15      15.9       5.0          1.2  11:32103059-32103697_ChrDown
# 4           15      15.9       5.0          1.2  11:32103225-32104031_ChrDown
# 5           12       9.8       0.0          0.0  11:32103225-32104031_ChrDown
# ...        ...       ...       ...          ...                           ...
# 1136       360      18.2       3.0          0.0      GL019525:4283-4501_ScfUp
# 1137       360      18.2       3.0          0.0    GL019525:4303-5039_ScfNumt
# 1138        16       0.0       0.0          0.0    GL019525:5691-6204_ScfNumt
# 1139        12      16.7       4.5          4.5      GL019525:6834-7105_ScfUp
# 1140       394      18.1       0.0          0.0    GL019525:7376-7647_ScfDown
#
#       qry_start  qry_end qry_left matching_repeat        repeat_id  \
# 1           460      507     (96)               +          GA-rich
# 2           428      475    (160)               +          GA-rich
# 3           424      471    (168)               +          GA-rich
# 4           258      305    (502)               +          GA-rich
# 5           644      665    (142)               +          (TTTA)n
# ...         ...      ...      ...             ...              ...
# 1136         43      108    (111)               +  tRNA-Ser-TCA(m)
# 1137         23       88    (649)               +  tRNA-Ser-TCA(m)
# 1138        362      378    (136)               +             (T)n
# 1139        174      217     (55)               +       (TTAATGA)n
# 1140         12       83    (189)               +   tRNA-Gln-CAA_v
#
#       matching_class no_bp_in_complement  in_repeat_start in_repeat_end  \
# 1     Low_complexity                   1               49           (0)
# 2     Low_complexity                   1               49           (0)
# 3     Low_complexity                   1               49           (0)
# 4     Low_complexity                   1               49           (0)
# 5      Simple_repeat                   1               22           (0)
# ...              ...                 ...              ...           ...
# 1136            tRNA                   1               68           (5)
# 1137            tRNA                   1               68           (5)
# 1138   Simple_repeat                   1               17           (0)
# 1139   Simple_repeat                   1               44           (0)
# 1140            tRNA                   1               72           (0)
#
#       qry_width
# 1            48
# 2            48
# 3            48
# 4            48
# 5            22
# ...         ...
# 1136         66
# 1137         66
# 1138         17
# 1139         44
# 1140         72
#
# [1140 rows x 15 columns]
