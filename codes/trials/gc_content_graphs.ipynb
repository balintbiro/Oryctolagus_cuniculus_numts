# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
gc_content = pd.read_csv(r'C:\Users\micha\Documents\Thesis\Code writing\Data\gc_content.csv')

# %%
ax = sns.boxplot(data=gc_content)
ax.set_ylabel('GC content')
plt.show()

# %%
ax = sns.violinplot(data=gc_content)
ax.set_ylabel('GC content')
plt.show()
