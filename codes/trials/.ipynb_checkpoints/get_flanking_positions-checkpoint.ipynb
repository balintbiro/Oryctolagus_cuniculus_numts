# %%
import pandas as pd

# %%
pd.read_csv(r'Z:\balint\numt\Michael\data/1_repeats (2)', sep = '\t')
# Out:
#        #bin  swScore  milliDiv  milliDel  milliIns genoName  genoStart  \
# 0      1123     1434       171         0         0     chr1   70610113
# 1      1123       28         0         0         0     chr1   70610351
# 2      1123      636       160         0         0     chr1   70610415
# 3      1123     1277       174       151        20     chr1   70610518
# 4      1123     3237       265        68        31     chr1   70610817
# ...     ...      ...       ...       ...       ...      ...        ...
# 10008  1161     3569       196        60         6     chr1   75608106
# 10009  1161     1788       157        62         9     chr1   75609201
# 10010  1161      305       217         0       135     chr1   75609555
# 10011  1161     2077       122        36        30     chr1   75609629
# 10012  1161      305       217         0       135     chr1   75609966
#
#         genoEnd   genoLeft strand  repName        repClass       repFamily  \
# ...
